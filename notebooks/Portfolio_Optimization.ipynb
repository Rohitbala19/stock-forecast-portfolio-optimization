# %% [markdown]
# # L1-Regularized Mean-Variance Portfolio Optimization & Backtesting
#
# This notebook runs the mean-variance optimizer under sparse long-only constraints using SciPy, performs rolling backtests over a 5-year period for all three models (MA, LR, LSTM), and plots the compounded equity curves.

# %%
# Step 1: Run Portfolio Optimization and Rolling Backtests
from portfolio_optimization import main as run_optimization
run_optimization()

# %% [markdown]
# ### Output Files
# The backtests have generated:
# - `MA_Portfolio_Returns.csv`
# - `LR_Portfolio_Returns.csv`
# - `LSTM_Portfolio_Returns.csv`
# - `equity_growth_curve.png` (Visual plot of performance)
