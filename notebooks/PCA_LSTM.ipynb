# %% [markdown]
# # PCA-LSTM Deep Learning Forecasting Model
#
# This notebook runs the feature engineering pipeline (returns, volatility, Z-scores), scales the data, reduces dimensions using PCA, trains the LSTM architecture, and generates multi-step price forecasts.

# %%
# Step 1: Perform Feature Engineering
from feature_engineering import feature_engineering
feature_engineering()

# %%
# Step 2: Train and Evaluate PCA-LSTM Model
# (Use --quick or epochs parameter to configure training)
import sys
sys.argv = ['train_pca_lstm.py', '--quick']  # Set to '--quick' for fast verification (3 epochs)
from train_pca_lstm import main as run_lstm
run_lstm()

# %% [markdown]
# ### Output Files
# The LSTM run has generated:
# - `PCA_Predicted_Prices1.csv`
# - `PCA_Actual_Prices1.csv`
