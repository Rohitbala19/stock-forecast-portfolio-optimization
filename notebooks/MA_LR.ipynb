# %% [markdown]
# # Moving Average & Linear Regression Baselines
#
# This notebook downloads historical stock data, performs feature engineering, and evaluates the Moving Average and Linear Regression baseline forecasting models.

# %%
# Step 1: Download Data
from download_data import download_data
download_data()

# %%
# Step 2: Pivot Closing Prices
from pivot_data import pivot_data
pivot_data()

# %%
# Step 3: Train and Evaluate Moving Average and Linear Regression
from train_ma_lr import main as run_baselines
run_baselines()

# %% [markdown]
# ### Output Files
# The baseline runs have generated:
# - `MovingAverage.csv`
# - `LR_Predicted_Prices.csv`
# - `LR_Actual_Prices.csv`
